# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanatanna/Loan_Prediction/blob/main/LoanPrediction_AnalyticsVidhya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOAN PREDICTION
# NAME: SANJANA TANNA
# ROLL NO: L040
# SUBJECT: DWR PRACTICAL

# %%
import pandas as pd
df=pd.read_csv('/content/train_ctrUa4K (1).csv')
df.head(4)

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# EDA:
#
# UNIVARIATE ANALYSIS
# BIVARIATE ANALYSIS
# OUTLIER TREATMENT
# MISSING VALUE TREATIMENT
# VARIABLE CREATION
# VARIABLE TRANSFORMATION
# EXPLORATORY DATA ANALYSIS:
#
# UNIVARIATE ANALYSIS: checks and analyzes each variable separately
#
# BIVARIATE ANALYSIS:
#
# A DATASET CAN ONLY HAVE ONE DEPENDENT VARIABLE AND CAN HAVE MULTIPLE INDEPENDENT VARIABLE
#
# DEPENDENT VARIABLE VS INDEPENDENT VARIABLE There should be a strong relationship between the two
#
# INDEPENDENT VARIABLE VS INDEPENDENT VARIABLE There should be a weak relation between the two, why?find out

# %%
df.corr(numeric_only= True) #checking multi collinearity in independent variables
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %% [markdown]
# TWO WAYS TO CHECK MULTICOLLINEARITY
#
# Variance Inflatio n Factors(vif) 0-3= NO COLLINEARITY 3-5=L0W COLLINEARITY 5-10= A BIT HIGH BUT SUBJECTIVE df.corr
#
# CORRELATION is something exisiting only in continuous variables it is not there in categorical variables

# %%
df['total_income']= df['CoapplicantIncome']+df['ApplicantIncome']
df.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status  total_income
# 0             1.0         Urban           Y        5849.0
# 1             1.0         Rural           N        6091.0
# 2             1.0         Urban           Y        3000.0
# 3             1.0         Urban           Y        4941.0

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  total_income
# count      564.000000    614.000000
# mean         0.842199   7024.705081
# std          0.364878   6458.663872
# min          0.000000   1442.000000
# 25%          1.000000   4166.000000
# 50%          1.000000   5416.500000
# 75%          1.000000   7521.750000
# ...

# %%
df['Loan_Amount_Term'].value_counts(normalize=True)*100 #relative frequency in terms of sum (total divide by ndividual value)
# Out:
# Loan_Amount_Term
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: proportion, dtype: float64

# %%
df['Credit_History'].value_counts(normalize= True)
# Out:
# Credit_History
# 1.0    0.842199
# 0.0    0.157801
# Name: proportion, dtype: float64

# %%
import seaborn as sns
sns.boxplot(x=df['total_income'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='total_income'>

# %%
#too much skewed on the right the right tail is so long no matter how many outliers treatment it will always remain skewed
#for this we perform variable transformation
sns.distplot(df['total_income'])
# Out:
# <ipython-input-156-812e2eedc2b1>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_income'])
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
import numpy as np
sns.distplot(np.log(df['total_income']))
# Out:
# <ipython-input-157-baeb5391b5bf>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['total_income']))
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
df['total_income_log']= np.log(df['total_income'])

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  total_income  total_income_log
# count      564.000000    614.000000        614.000000
# mean         0.842199   7024.705081          8.669414
# std          0.364878   6458.663872          0.545102
# min          0.000000   1442.000000          7.273786
# ...

# %%
sns.boxplot(x=df['total_income_log'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='total_income_log'>

# %%
m3s= np.mean(df.total_income_log)+ 3*np.std(df.total_income_log)

# %%
pqq= np.percentile(df.total_income_log,99)

# %%
m3s
# Out:
# 10.30338594912378

# %%
pqq
# Out:
# 10.530669145261063

# %%
IQR = np.percentile(df.total_income_log,75)+1.5*(np.percentile(df.total_income_log,75)-np.percentile(df.total_income_log,25))

# %%
IQR
# Out:
# 9.8118061598248

# %%
Mean= df.loc[df.total_income_log>m3s,"Loan_ID"].count()
Mean1= df.loc[df.total_income_log>IQR,"Loan_ID"].count()
Mean2=df.loc[df.total_income_log>pqq,"Loan_ID"].count()

# %%
print(Mean,Mean1,Mean2)
# Out:
# 9 21 7

# %%
Mean
# Out:
# 9

# %%
pqq1= np.percentile(df.total_income_log,99.5)

# %%
pqq1
# Out:
# 10.686858121671433

# %%
sns.distplot(np.where(df['total_income_log']>pqq,pqq,df['total_income_log']))
# Out:
# <ipython-input-172-86c9de5ef45c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.where(df['total_income_log']>pqq,pqq,df['total_income_log']))
# <Axes: ylabel='Density'>

# %%
df['total_income_log']= np.where(df['total_income_log']>pqq,pqq,df['total_income_log'])

# %%
sns.boxplot(x=df['total_income_log'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='total_income_log'>

# %%
np.percentile(df.total_income_log,1) #not too much difference between the minimum value and the first percentile therefore no need to remove that outlier
#mean - 3sd is less than minimum -therfore it is not a outlier
# Out:
# 7.669257532935698

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  total_income  total_income_log
# count      564.000000    614.000000        614.000000
# mean         0.842199   7024.705081          8.666206
# std          0.364878   6458.663872          0.532448
# min          0.000000   1442.000000          7.273786
# ...

# %%
sns.boxplot(x=df['LoanAmount'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='LoanAmount'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# <ipython-input-178-4fe14db8f0cd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
np.percentile(df.LoanAmount,95)
# Out:
# nan

# %%
np.percentile(df.LoanAmount,96)
# Out:
# nan

# %%
for value in [95,96,97,98,99,99.5,100]:
  print(f" {value}:{np.percentile(df['LoanAmount'].dropna(),value)}")

#there is a high jump after 99
# Out:
#  95:297.7999999999997
#  96:316.80000000000007
#  97:362.6999999999998
#  98:443.9199999999978
#  99:496.3600000000001
#  99.5:600.0
#  100:700.0

# %%
m3s= np.mean(df.LoanAmount)+ 3*np.std(df.LoanAmount)

# %%
p99= np.percentile(df.LoanAmount.dropna(),99)

# %%
IQR = np.percentile(df.LoanAmount.dropna(),75)+1.5*(np.percentile(df.LoanAmount.dropna(),75)-np.percentile(df.LoanAmount.dropna(),25))

# %%
print(m3s,p99,IQR)
# Out:
# 402.9571864357721 496.3600000000001 270.0

# %%
sns.distplot(np.where(df['LoanAmount']>p99,p99,df['LoanAmount']))
# Out:
# <ipython-input-186-e9a5e40f3fc9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.where(df['LoanAmount']>p99,p99,df['LoanAmount']))
# <Axes: ylabel='Density'>

# %% [markdown]
# ## MISSING VALUE TREATMENT

# %%
sns.distplot(df['Loan_Amount_Term']) #NORMAL DISTRIBUTION DOES NOT WORK ON DISCRETE DATA THEREFORE YOU MAKE A FREQUENCY DISTRIBUTION TABLE
# Out:
# <ipython-input-187-2b5359c6ae6b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term']) #NORMAL DISTRIBUTION DOES NOT WORK ON DISCRETE DATA THEREFORE YOU MAKE A FREQUENCY DISTRIBUTION TABLE
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %% [markdown]
# CHECK RELEVANCE OF THIS VARIABLE DURING BIVARIATE ANALYSIS
# DATA IS BIASED IN LOAN_AMOUNT_TERM THEREFORE IT MIGHT NOT BE
# USEFUL NOW

# %%
df['Loan_Amount_Term'].value_counts(normalize=True)*100
# Out:
# Loan_Amount_Term
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: proportion, dtype: float64

# %%
df['Credit_History'].fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0        77.361564
# 0.0        14.495114
# MISSING     8.143322
# Name: proportion, dtype: float64

# %%
df['Credit_History'].fillna(0,inplace=True)
# Out:
# <ipython-input-191-9314db411aaf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Credit_History'].fillna(0,inplace=True)

# %%
df['Credit_History'].value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0    77.361564
# 0.0    22.638436
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# total_income          0
# total_income_log      0
# dtype: int64

# %%
df['Gender'].fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Gender
# Male       79.641694
# Female     18.241042
# MISSING     2.117264
# Name: proportion, dtype: float64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# total_income         0.000000
# total_income_log     0.000000
# dtype: float64

# %%
pd.crosstab(df.Gender.fillna('MISSING'),df.Married)
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# MISSING    3   10
# Male     130  357

# %%
pd.crosstab(df.Gender.fillna('MISSING'),df.Self_Employed)
# Out:
# Self_Employed   No  Yes
# Gender
# Female          89   15
# MISSING          9    4
# Male           402   63

# %%
df['Gender'].fillna("Male",inplace=True)
# Out:
# <ipython-input-198-1da97167b3bb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna("Male",inplace=True)

# %%
df['Gender'].fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Gender
# Male      81.758958
# Female    18.241042
# Name: proportion, dtype: float64

# %%
df['Married'].fillna('Yes',inplace=True)
# Out:
# <ipython-input-200-c05ef96aac0f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Married'].fillna('Yes',inplace=True)

# %%
df['Married'].value_counts(normalize=True)
# Out:
# Married
# Yes    0.653094
# No     0.346906
# Name: proportion, dtype: float64

# %%
sns.scatterplot(data=df,x='total_income',y='LoanAmount') #not applicable as relationship breaks after a while
# Out:
# <Axes: xlabel='total_income', ylabel='LoanAmount'>

# %%
df['Dependents'].value_counts(normalize=True) #check if it can be helped through any numeric data
# Out:
# Dependents
# 0     0.575960
# 1     0.170284
# 2     0.168614
# 3+    0.085142
# Name: proportion, dtype: float64

# %%
sns.violinplot(x=df.Dependents.fillna('MISSING'),y=df.total_income) #since the missing value matches with the 2s data you replace the missing value with the 2's value
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df['Dependents'].fillna(2,inplace=True)
# Out:
# <ipython-input-205-de6059e29420>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].fillna(2,inplace=True)

# %%
sns.violinplot(x=df.Dependents.fillna('MISSING'),y=df.total_income) #violin plot is used for comparing categorical data with numerical data helps for better comparision between these 2
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# total_income          0
# total_income_log      0
# dtype: int64

# %%
pd.crosstab([df.Education,df.Property_Area],df.Self_Employed.fillna('MISSING'))
# Out:
# Self_Employed               MISSING   No  Yes
# Education    Property_Area
# Graduate     Rural                6  104   21
#              Semiurban            8  154   25
#              Urban               12  131   19
# Not Graduate Rural                4   39    5
#              Semiurban            2   37    7
#              Urban                0   35    5

# %%
sns.violinplot(x=df.Self_Employed.fillna('MISSING'),y=df.total_income)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Self_Employed', ylabel='total_income'>

# %%
sns.violinplot(x=df.Self_Employed.fillna('MISSING'),y=df.LoanAmount)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
df['Self_Employed'].fillna('Yes',inplace=True)
# Out:
# <ipython-input-211-5066fd66ea42>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Self_Employed'].fillna('Yes',inplace=True)

# %%
df['Self_Employed'].value_counts(normalize=True)
# Out:
# Self_Employed
# No     0.814332
# Yes    0.185668
# Name: proportion, dtype: float64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# total_income         0.000000
# total_income_log     0.000000
# dtype: float64

# %%
sns.scatterplot(data=df,x='total_income',y='LoanAmount')
# Out:
# <Axes: xlabel='total_income', ylabel='LoanAmount'>

# %%
sns.violinplot(x=df.Property_Area,y=df.LoanAmount) #not applicable
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
df.groupby('Property_Area')['LoanAmount'].mean()
# Out:
# Property_Area
# Rural        152.260116
# Semiurban    145.504386
# Urban        142.198953
# Name: LoanAmount, dtype: float64

# %%
df.groupby('Self_Employed')['LoanAmount'].mean()
# Out:
# Self_Employed
# No     141.748963
# Yes    166.845455
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Self_Employed','Property_Area'])['LoanAmount'].mean() #one eg: the missing value in where self employed
#is no and property area is rural the we will replace the missing value with that loan amount mean next to it
# Out:
# Self_Employed  Property_Area
# No             Rural            149.079710
#                Semiurban        143.973404
#                Urban            132.583333
# Yes            Rural            164.800000
#                Semiurban        152.700000
#                Urban            185.057143
# Name: LoanAmount, dtype: float64

# %%
df1= df.loc[df.LoanAmount.isnull(),['Self_Employed','Property_Area']]

df1.groupby(["Self_Employed","Property_Area"])['Property_Area'].count()
# Out:
# Self_Employed  Property_Area
# No             Rural             5
#                Semiurban         3
#                Urban            10
# Yes            Rural             1
#                Semiurban         2
#                Urban             1
# Name: Property_Area, dtype: int64

# %%
df.LoanAmount.fillna(df.groupby(['Self_Employed','Property_Area'])['LoanAmount'].transform("mean"),inplace=True)
# Out:
# <ipython-input-220-bb8f1c827e47>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.LoanAmount.fillna(df.groupby(['Self_Employed','Property_Area'])['LoanAmount'].transform("mean"),inplace=True)

# %%
sns.distplot(df['LoanAmount'])
# Out:
# <ipython-input-221-4fe14db8f0cd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.violinplot(x=df.Loan_Amount_Term.fillna('MISSING VALUES'),y=df.LoanAmount)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.Loan_Amount_Term.value_counts(normalize=True)*100
# Out:
# Loan_Amount_Term
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: proportion, dtype: float64

# %%
sns.violinplot(x=df.Loan_Amount_Term.fillna('MISSING VALUES'),y=df.total_income)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
pd.crosstab(df['Loan_Amount_Term'].fillna("MISSING VALUES"),df['Self_Employed'])
# Out:
# Self_Employed      No  Yes
# Loan_Amount_Term
# 12.0                1    0
# 36.0                2    0
# 60.0                1    1
# 84.0                3    1
# 120.0               2    1
# 180.0              35    9
# 240.0               3    1
# 300.0              10    3
# 360.0             418   94
# 480.0              14    1
# MISSING VALUES     11    3

# %%
df['Loan_Amount_Term'].fillna(df.Loan_Amount_Term.mode()[0],inplace=True)
# Out:
# <ipython-input-226-6e4ca73323fd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].fillna(df.Loan_Amount_Term.mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# total_income         0
# total_income_log     0
# dtype: int64

# %%
test= pd.read_csv('/content/test_lAUu6dG (1).csv')

# %%
test['total_income']= test['CoapplicantIncome']+test['ApplicantIncome']

# %%
test['total_income_log']= np.log(test['total_income'])

# %%
m3s= np.mean(test.total_income_log)+ 3*np.std(test.total_income_log)
pqq= np.percentile(test.total_income_log,99)
IQR = np.percentile(test.total_income_log,75)+1.5*(np.percentile(test.total_income_log,75)-np.percentile(test.total_income_log,25))

Mean= test.loc[test.total_income_log>m3s,"Loan_ID"].count()
Mean1= test.loc[test.total_income_log>IQR,"Loan_ID"].count()
Mean2=test.loc[test.total_income_log>pqq,"Loan_ID"].count()

# %%
sns.distplot(np.where(test['LoanAmount']>p99,p99,test['LoanAmount']))



test['Credit_History'].fillna(0,inplace=True)

test['Gender'].fillna("Male",inplace=True)

test['Married'].fillna('Yes',inplace=True)

test['Dependents'].fillna(2,inplace=True)

test['Self_Employed'].fillna('Yes',inplace=True)

test.LoanAmount.fillna(test.groupby(['Self_Employed','Property_Area'])['LoanAmount'].transform("mean"),inplace=True)

test['Loan_Amount_Term'].fillna(test.Loan_Amount_Term.mode()[0],inplace=True)
# Out:
# <ipython-input-232-5f73de878ece>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.where(test['LoanAmount']>p99,p99,test['LoanAmount']))
# <ipython-input-232-5f73de878ece>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
test.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# total_income         0
# total_income_log     0
# dtype: int64

# %%
final= pd.concat([df,test],axis=0)

# %%
df.shape
# Out:
# (614, 15)

# %%
test.shape
# Out:
# (367, 14)

# %%
final.shape
# Out:
# (981, 15)

# %% [markdown]
# MODEL IMPLEMENTATION

# %%
train= df.copy()

test1= test.copy()

# %%
train_1 = train.drop(['total_income','ApplicantIncome','CoapplicantIncome','Loan_ID'],axis=1)

# %%
test_1= test1.drop(['total_income','ApplicantIncome','CoapplicantIncome','Loan_ID'],axis=1)

# %%
train_Y= train_1['Loan_Status']
train_X= train_1.drop(['Loan_Status'],axis=1)
test_X= test_1.copy()

# %%
train_X=pd.get_dummies(train_X,drop_first=True)

# %%
test_X=pd.get_dummies(test_X,drop_first=True)

# %%
from sklearn.linear_model import LogisticRegression

LR= LogisticRegression()
LR.fit(train_X,train_Y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LR.predict(test_X)
# Out:
# array(['Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
# ...

# %%
test_X.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'total_income_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
train_X.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'total_income_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
test_X.isna().sum()
# Out:
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# total_income_log           0
# Gender_Male                0
# Married_Yes                0
# Dependents_0               0
# Dependents_1               0
# Dependents_2               0
# Dependents_3+              0
# Education_Not Graduate     0
# Self_Employed_Yes          0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
train_X.isna().sum()
# Out:
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# total_income_log           0
# Gender_Male                0
# Married_Yes                0
# Dependents_0               0
# Dependents_1               0
# Dependents_2               0
# Dependents_3+              0
# Education_Not Graduate     0
# Self_Employed_Yes          0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
pred= LR.predict(test_X)

pred
# Out:
# array(['Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
# ...

# %%
test_X.head()
# Out:
#    LoanAmount  Loan_Amount_Term  Credit_History  total_income_log  \
# 0       110.0             360.0             1.0          8.651724
# 1       126.0             360.0             1.0          8.428581
# 2       208.0             360.0             1.0          8.824678
# 3       100.0             360.0             0.0          8.494129
# 4        78.0             360.0             1.0          8.094378
#
#    Gender_Male  Married_Yes  Dependents_0  Dependents_1  Dependents_2  \
# 0         True         True          True         False         False
# 1         True         True         False          True         False
# 2         True         True         False         False          True
# 3         True         True         False         False          True
# 4         True        False          True         False         False
#
#    Dependents_3+  Education_Not Graduate  Self_Employed_Yes  \
# 0          False                   False              False
# ...

# %%
pred= pd.concat([test1.Loan_ID,pd.DataFrame(pred)],axis=1)

pred.columns=['Loan_ID','Loan_Status']

# %%
pred.to_csv("pred_LR.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt= DecisionTreeClassifier()

# %%
print(dt)
# Out:
# DecisionTreeClassifier()

# %%
dt.fit(train_X,train_Y)
# Out:
# DecisionTreeClassifier()

# %%
pred1= dt.predict(test_X)

pred1
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'N',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y',
# ...

# %%
pred1= pd.concat([test1.Loan_ID,pd.DataFrame(pred1)],axis=1)

pred1.columns=['Loan_ID','Loan_Status']

# %%
pred1.to_csv("pred1_dt.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier()

# %%
rf.fit(train_X,train_Y)
# Out:
# RandomForestClassifier()

# %%
pred2= rf.predict(test_X)

pred2
# Out:
# array(['Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N',
# ...

# %%
pred2= pd.concat([test1.Loan_ID,pd.DataFrame(pred2)],axis=1)

pred2.columns=['Loan_ID','Loan_Status']

# %%
pred2.to_csv("pred2_rf.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from sklearn.metrics import *

# %%
from sklearn.metrics import *

model_parameter={'n_estimators':[100,500],'min_samples_leaf'=[1,5,10,20,50],'ccp_alpha'=[0,0,5,1]}

from sklearn.model_selection import GridSearchCV
gscv=GridSearchCV(estimator=rf,param_grid=model_parameter,cv=5,verbose=1,n_jobs=-1)

gscv.fit(train_X,train_Y)

gscv.best_params_

# %%
model_parameter={'n_estimators':[100,500],
                'min_samples_leaf':[1,5,10,20,50],'ccp_alpha':[0,0.5,1]}

# %%
#reg_R=Ridge()
from sklearn.model_selection import GridSearchCV
gscv=GridSearchCV(estimator=rf,
                 param_grid=model_parameter,
                 cv=5,
                 verbose=1,
                 n_jobs=-1)

gscv.fit(train_X,train_Y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'ccp_alpha': [0, 0.5, 1],
#                          'min_samples_leaf': [1, 5, 10, 20, 50],
#                          'n_estimators': [100, 500]},
#              verbose=1)

# %%
gscv.best_params_
# Out:
# {'ccp_alpha': 0, 'min_samples_leaf': 5, 'n_estimators': 500}

# %%
reg_R_final=RandomForestClassifier(ccp_alpha=0, min_samples_leaf= 5, n_estimators= 500)
reg_R_final.fit(train_X,train_Y)
# Out:
# RandomForestClassifier(ccp_alpha=0, min_samples_leaf=5, n_estimators=500)

# %%
pred3= reg_R_final.predict(test_X)


pred3= pd.concat([test1.Loan_ID,pd.DataFrame(pred3)],axis=1)

pred3.columns=['Loan_ID','Loan_Status']

# %%
pred3.to_csv("parameter tuning.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import xgboost
from xgboost import XGBClassifier

# %%
xgb= XGBClassifier()

# %%
xgb.fit(train_X,train_Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-304-3e957d113aef> in <cell line: 1>()
# ----> 1 xgb.fit(train_X,train_Y)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#     727
#     728         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1489                 or not (classes == expected_classes).all()
#    1490             ):
# -> 1491                 raise ValueError(
#    1492                     f"Invalid classes inferred from unique values of `y`.  "
# ...
